# %%
import pandas as pd
import os
import path
files_dir = '/Users/Priyanka Sawant/Documents/Sem2/BI/'
pth = path.Path(files_dir)
files = os.listdir(pth/'logs')
print(files)
# Out:
# ['.DS_Store', 'u_ex091024.log', 'u_ex091025.log', 'u_ex091102.log', 'u_ex091103.log', 'u_ex091106.log', 'u_ex091120.log', 'u_ex091123.log', 'u_ex091207.log', 'u_ex091211.log', 'u_ex091213.log', 'u_ex100104.log', 'u_ex100105.log', 'u_ex100106.log', 'u_ex100112.log', 'u_ex100113.log', 'u_ex100117.log', 'u_ex100131.log', 'u_ex100204.log', 'u_ex100205.log', 'u_ex100221.log', 'u_ex100302.log', 'u_ex100304.log', 'u_ex100307.log', 'u_ex100309.log', 'u_ex100314.log', 'u_ex100315.log', 'u_ex100322.log', 'u_ex100406.log', 'u_ex100419.log', 'u_ex100422.log', 'u_ex100423.log', 'u_ex100424.log', 'u_ex100425.log', 'u_ex100430.log', 'u_ex100519.log', 'u_ex100520.log', 'u_ex100526.log', 'u_ex100528.log', 'u_ex100612.log', 'u_ex100615.log', 'u_ex100619.log', 'u_ex100622.log', 'u_ex100626.log', 'u_ex100628.log', 'u_ex100629.log', 'u_ex100630.log', 'u_ex100705.log', 'u_ex100708.log', 'u_ex100714.log', 'u_ex100718.log', 'u_ex100725.log', 'u_ex100801.log', 'u_ex100808.log', 'u_ex100809.log', 'u_ex100830.
# ...

# %%
files = [file for file in files if file.endswith(".log") ]

# %%
file_countr=0
from tqdm.notebook import tqdm
for file in tqdm(files):
    
    with open(pth/'logs'/file) as f:
        lines = f.readlines()
    
    primary=0
    toggle = 0
    datas=[]
    
    for line in lines:
        if line.startswith('#Fields'):

            toggle = 1
            primary=1

        elif line.startswith('#'):

            toggle = 0


        if primary == 1 and toggle == 0:
            temp = pd.DataFrame(datas,columns = fields)
            temp.to_csv(pth/'temp'/f'log_{file_countr}.csv',index=False)
            datas = []
            file_countr = file_countr+1
            primary = 0


        if toggle == 1:
            if line.startswith('#Fields'):

                fields = line.replace('#Fields: ', '')
                fields = fields.split(' ')

            else:
                data = line.split(' ')
                datas.append(data)

        elif toggle == 0:
            print('done')



    temp = pd.DataFrame(datas,columns = fields)
    temp.to_csv(pth/'processed'/f'log_{file_countr}.csv',index=False)
    datas = []
    file_countr = file_countr+1
    primary = 0
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
files = os.listdir(pth/'processed')
files = [file for file in files if file.endswith(".csv") ]

# %%
final_data = []
for file in tqdm(files):
    
    temp =pd.read_csv(pth/'temp'/file)
    final_data.append(temp)
# Out:
#   0%|          | 0/671 [00:00<?, ?it/s]

# %%
final_df = pd.concat(final_data,axis=0)

# %%
final_df.head(8)
# Out:
#          date      time          s-ip cs-method        cs-uri-stem  \
# 0  2009-10-24  01:40:40  134.36.36.75      HEAD                  /
# 1  2009-10-24  01:40:43  134.36.36.75       GET                  /
# 2  2009-10-24  01:40:43  134.36.36.75       GET  /Darwin/Home.aspx
# 3  2009-10-24  01:41:17  134.36.36.75       GET                  /
# 4  2009-10-24  01:41:17  134.36.36.75       GET        /robots.txt
# 0  2009-10-24  08:34:52  134.36.36.75       GET           /abc.php
# 0  2009-11-02  14:00:35  134.36.36.75       GET                  /
# 1  2009-11-02  14:00:35  134.36.36.75       GET  /Darwin/Home.aspx
#
#                                         cs-uri-query  s-port cs-username  \
# 0                                                  -      80           -
# 1                                                  -      80           -
# 2                                                  -      80           -
# ...

# %%
final_df.rename(columns={'time-taken\n':'time-taken'}, inplace=True)

# %%
final_df.head()
# Out:
#          date      time          s-ip cs-method        cs-uri-stem  \
# 0  2009-10-24  01:40:40  134.36.36.75      HEAD                  /
# 1  2009-10-24  01:40:43  134.36.36.75       GET                  /
# 2  2009-10-24  01:40:43  134.36.36.75       GET  /Darwin/Home.aspx
# 3  2009-10-24  01:41:17  134.36.36.75       GET                  /
# 4  2009-10-24  01:41:17  134.36.36.75       GET        /robots.txt
#
#   cs-uri-query  s-port cs-username             c-ip  \
# 0            -      80           -  205.178.184.153
# 1            -      80           -  205.178.184.153
# 2            -      80           -  205.178.184.153
# 3            -      80           -  205.178.184.153
# 4            -      80           -  205.178.184.153
#
#                                       cs(User-Agent)  sc-status  sc-substatus  \
# 0  Mozilla/5.0+(Windows;+U;+Windows+NT+5.1;+en-US...        200             0
# 1  Mozilla/4.0+(compatible;+MSIE+7.0;+Windows+NT+...        200             0
# ...

# %%
import os
final_df.to_csv('data_final.csv',index=False)
